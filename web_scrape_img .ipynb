# %%
# Out:
#   File "<ipython-input-1-be977c6edf4b>", line 1
#     import lxml from html
#                    ^
# SyntaxError: invalid syntax

# %%
from lxml import html

# %%
import requests

# %%
page = requests.get("https://www.google.com/search?q=harshita+diddee&source=lnms&tbm=isch&sa=X&ved=0ahUKEwim3eHT1P7dAhXaZCsKHVYuA-MQ_AUIDigB&biw=1853&bih=951")
print(page.content)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><noscript><meta content="0;url=/search?q=harshita+diddee&amp;tbm=isch&amp;sa=X&amp;biw=1853&amp;bih=951&amp;ie=UTF-8&amp;gbv=1&amp;sei=qma_W8XyHIfSvwS1_qPwCg" http-equiv="refresh"><style>table,div,span,p{display:none}</style><div style="display:block">Please click <a href="/search?q=harshita+diddee&amp;tbm=isch&amp;sa=X&amp;biw=1853&amp;bih=951&amp;ie=UTF-8&amp;gbv=1&amp;sei=qma_W8XyHIfSvwS1_qPwCg">here</a> if you are not redirected within a few seconds.</div></noscript><title>harshita diddee - Google Search</title><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:abs
# ...

# %%
page.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup as BS

# %%
soup = BS(page.content, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# ...

# %%
list = soup.find_all('img')
print(list)
# Out:
# [<img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjmdTpYv62sB4BdyFhLR7zumgyHmi8IgaicIOg6mXyz8Sd_wKONpf11kw" width="125"/>, <img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSE67ampPS3a5gIeNi65ZfwoD56t_ubxq3xPDEbdBIjKchjSiuuTfxO7Q" width="125"/>, <img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbd1x5fxFYY1sYqtpilx3af1lUABa98R2PetqsGY_U8wTdzqzZzUXmsiE" width="125"/>, <img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTgzIQQFVbEXGaTlRXtVjAFz-fXJYq17qF5HSZH5kgOACqxiPmBpSAitfo" width="125"/>, <img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTdu75CKKdzdLCMtDA2hfJ7tjlm6NKIcjmp77zd8jhXb3WTqBBPvb9Z6A" width="125"/>, <img alt="Image result for harshita diddee" heigh
# ...

# %%
list = soup.find_all('img')

# %%
list
# Out:
# [<img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjmdTpYv62sB4BdyFhLR7zumgyHmi8IgaicIOg6mXyz8Sd_wKONpf11kw" width="125"/>,
#  <img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSE67ampPS3a5gIeNi65ZfwoD56t_ubxq3xPDEbdBIjKchjSiuuTfxO7Q" width="125"/>,
#  <img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbd1x5fxFYY1sYqtpilx3af1lUABa98R2PetqsGY_U8wTdzqzZzUXmsiE" width="125"/>,
#  <img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTgzIQQFVbEXGaTlRXtVjAFz-fXJYq17qF5HSZH5kgOACqxiPmBpSAitfo" width="125"/>,
#  <img alt="Image result for harshita diddee" height="126" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTdu75CKKdzdLCMtDA2hfJ7tjlm6NKIcjmp77zd8jhXb3WTqBBPvb9Z6A" width="125"/>,
# ...

# %%
print(list)
# Out:
# [<div class="interstitialblock muOverlay" id="interstitialblock"></div>, <div class="display--none"><svg xmlns="http://www.w3.org/2000/svg"><defs><path d="M-293 385h23.7v24H-293z" id="outlook-SVGID_1_"></path></defs><symbol id="icon-address" viewbox="0 0 20 20"><title>address</title><path d="M19.8 5.165l-2.376-1.83c-.135-.093-.324-.176-.52-.237-.2-.06-.404-.098-.568-.098H9.5l.8 5h6.036c.164 0 .37-.037.566-.098s.387-.145.52-.236L19.8 5.834c.135-.09.202-.212.202-.334s-.067-.243-.2-.335zM8.5 1h-1c-.276 0-.5.224-.5.5V5H3.664c-.166 0-.37.037-.567.1-.198.06-.387.142-.52.235L.2 7.165c-.134.09-.2.213-.2.335 0 .12.066.242.2.335l2.376 1.832c.134.09.323.175.52.235.198.06.402.098.568.098H7v8.5c0 .276.224.5.5.5h1c.276 0 .5-.224.5-.5v-17c0-.276-.224-.5-.5-.5z"></path></symbol><symbol id="icon-align-top" viewbox="0 0 20 20"><title>align-top</title><path d="M10 6L7 9h2v8h2V9h2l-3-3zm8-2c0-.553-.048-1-.6-1H2.6c-.552 0-.6.447-.6 1 0 .553.048 1 .6 1h14.8c.552 0 .6-.447.6-1z"></path></symbol><symbol id=
# ...

# %%
list_src=[item["src"] for item in soup.find_all('img alt') if "src" in item.attrs]
len(list_src)
import base64
coded_string = list_src[0];
print(base64.b64decode(coded_string))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-33599880b021> in <module>()
#       2 len(list_src)
#       3 import base64
# ----> 4 coded_string = list_src[0];
#       5 print(base64.b64decode(coded_string))
#
# IndexError: list index out of range

# %%
# list = soup.find_all({'class' : 'simple-category-option'})
# soup.prettify
# list = soup.find_all('a',{'class' : 'simple-category-option'})
# 
# list_cat=[item["data-name"] for item in soup.find_all('a',{'class':'simple-category-option'}) if "data-name" in item.attrs]
# cat_ref_dict={}
# n=len(list_ref)
# for i in range(2,n,1):
#     cat_ref_dict[list_cat[i]]=list_ref[i]
# cat_ref_dict
# Out:
# {'Arts': 'https://www.meetup.com/find/events/arts-culture/',
#  'Beliefs': 'https://www.meetup.com/find/events/beliefs/',
#  'Book Clubs': 'https://www.meetup.com/find/events/book-clubs/',
#  'Career & Business': 'https://www.meetup.com/find/events/career-business/',
#  'Dance': 'https://www.meetup.com/find/events/dancing/',
#  'Family': 'https://www.meetup.com/find/events/parents-family/',
#  'Fashion & Beauty': 'https://www.meetup.com/find/events/fashion-beauty/',
#  'Film': 'https://www.meetup.com/find/events/film/',
#  'Food & Drink': 'https://www.meetup.com/find/events/food/',
#  'Health & Wellness': 'https://www.meetup.com/find/events/health-wellness/',
#  'Hobbies & Crafts': 'https://www.meetup.com/find/events/hobbies-crafts/',
#  'LGBTQ': 'https://www.meetup.com/find/events/lgbtq/',
#  'Language & Culture': 'https://www.meetup.com/find/events/language/',
#  'Learning': 'https://www.meetup.com/find/events/education/',
# ...

# %%
list = soup.find_all("li")
list
# Out:
# [<li class="row-item padding--none padding-none " id="logoContainer">
#  <a href="https://www.meetup.com/" id="homeLink">
#  <img alt="Meetup home" class="" id="logoScript" src="https://secure.meetupstatic.com/s/img/5455565085016210254/logo/svg/logo--script.svg"/>
#  </a>
#  </li>, <li class="row-item row-item--shrink ">
#  <div class="row row--noGutters" id="ctaLinks">
#  <div class="row-item row-item--shrink display--none display-none atMedium_display--block " id="headerCreateLink">
#  <a class="headerTab omnCamp omnic_in_find" href="https://secure.meetup.com/create/">
#  <span class="headerTab-label">Start a new group</span>
#  </a>
#  </div>
#  <div class="row-item row-item--shrink display--none display-none atLarge_display--block flush--right">
#  <span id="nav-lang">
#  <form action="https://www.meetup.com/account/language/" class="margin--right" method="get">
#  <select class="text--small span-100" id="C_langs" name="lang">
# ...

# %%
from lxml import html
import requests 
page = requests.get("https://www.wired.com/")
from bs4 import BeautifulSoup as BS
soup = BS(page.content, 'html.parser')
soup.prettify
#print(soup)
list_ref=[item["href"] for item in soup.find_all('h2',{'class' : 'card-component__description card-component__description--narrow'}) if "href" in item.attrs]
# list_cat=[item["data-name"] for item in soup.find_all('a',{'class':'simple-category-option'}) if "data-name" in item.attrs]
# cat_ref_dict={}
# n=len(list_ref)
# for i in range(2,n,1):
#     cat_ref_dict[list_cat[i]]=list_ref[i]
# cat_ref_dict
list_ref   
print("over")
# Out:
# over

# %%
list = soup.find_all('data-key')
list
# Out:
# []

# %%
cat_dict={}

# %%
len(list)
# Out:
# 0

# %%
list = soup.find_all('a', {'class' : 'simple-category-option'})
print(list)
len(list)
# Out:
# [<a class="simple-category-option selected" data-key="*" data-name="*" href="#" id="allCriteria">
# <i class="icon-infinite"></i> All Meetups
# </a>, <a class="simple-category-option " data-key="__fb__" data-name="Meetups with friends" href="#" id="friendCriteria">
# <i class="icon-members"></i> Meetups with friends
# </a>, <a class="simple-category-option " data-key="arts-culture" data-name="Arts" href="https://www.meetup.com/find/events/arts-culture/">
# Arts
# </a>, <a class="simple-category-option " data-key="beliefs" data-name="Beliefs" href="https://www.meetup.com/find/events/beliefs/">
# Beliefs
# </a>, <a class="simple-category-option " data-key="book-clubs" data-name="Book Clubs" href="https://www.meetup.com/find/events/book-clubs/">
# Book Clubs
# </a>, <a class="simple-category-option " data-key="career-business" data-name="Career &amp; Business" href="https://www.meetup.com/find/events/career-business/">
# Career &amp; Business
# ...

# %%
list = soup.find_all('a',{'class' : 'simple-category-option'})
list_ref=[item["href"] for item in soup.find_all('a',{'class' : 'simple-category-option'}) if "href" in item.attrs]
list_cat=[item["data-name"] for item in soup.find_all('a',{'class':'simple-category-option'}) if "data-name" in item.attrs]
cat_ref_dict={}
n=len(list_ref)
for i in range(2,n,1):
    cat_ref_dict[list_cat[i]]=list_ref[i]
cat_ref_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c43eecaedd43> in <module>()
# ----> 1 list = soup.find_all('a',{'class' : 'simple-category-option'})
#       2 list_ref=[item["href"] for item in soup.find_all('a',{'class' : 'simple-category-option'}) if "href" in item.attrs]
#       3 list_cat=[item["data-name"] for item in soup.find_all('a',{'class':'simple-category-option'}) if "data-name" in item.attrs]
#       4 cat_ref_dict={}
#       5 n=len(list_ref)
#
# NameError: name 'soup' is not defined

# %%
# Import database module.
from firebase_admin import db

# Get a database reference to our blog.
ref = db.reference('https://event-lookup-51f70.firebaseio.com/')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-67-68b3653cd4b3> in <module>()
#       1 # Import database module.
# ----> 2 from firebase_admin import db
#       3
#       4 # Get a database reference to our blog.
#       5 ref = db.reference('https://event-lookup-51f70.firebaseio.com/')
#
# ModuleNotFoundError: No module named 'firebase_admin'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-b559b6911d36> in <module>()
# ----> 1 import firebase_admin
#
# ModuleNotFoundError: No module named 'firebase_admin'
